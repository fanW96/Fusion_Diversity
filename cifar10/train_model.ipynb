# %%
import tensorflow as tf
import keras as keras
import keras.backend as K
from resnet_keras_feature_fusion_v13 import ResNet_v13
from resnet_keras_feature_fusion_v12 import ResNet_v12
from resnet_keras_feature_fusion_v12_deconv import ResNet_v12_deconv
from resnet_keras_feature_fusion_v11 import ResNet_v11
from resnet_keras_feature_fusion_v10 import ResNet_v10
from resnet_keras_feature_fusion_v9 import ResNet_v9
from resnet_keras_feature_fusion_v8 import ResNet_v8
from resnet_keras_feature_fusion_v7 import ResNet_v7
from resnet_keras_feature_fusion_v6 import ResNet_v6
from resnet_keras_feature_fusion_v5 import ResNet_v5
from resnet_keras_feature_fusion_v4 import ResNet_v4
from resnet_keras_feature_fusion_v3 import ResNet_v3
from resnet_keras_feature_fusion_v2 import ResNet_v2
from resnet_keras import ResNet
# from test_cifar_iterative import attack_iterative
# from test_cifar_jsma import attack_jsma
# from test_cifar_optimization import attack_optimization
import cifar10
import time
# Out:
# /home/mastlab/.conda/envs/wf1-12/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/mastlab/.conda/envs/wf1-12/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/mastlab/.conda/envs/wf1-12/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
x_train, y_train, x_test, y_test = cifar10.get_data()

# %%
compare_regular = ResNet(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
compare_regular.train()

# %%
compare_FD = ResNet_v12(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
compare_FD.train()

# %%
test = ResNet_v12_deconv(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
test.train()

# %%
light_321 = ResNet_v13(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
light_321.train()

# %%
resnet = ResNet(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
resnet.train()

# %%
sgd321 = ResNet_v12(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
sgd321.train()

# %%
fusion = ResNet_v2(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
nofusion = ResNet_v3(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
nofusion_nodiversity = ResNet_v4(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
fusion_nodiversity = ResNet_v5(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
strongforhigher = ResNet_v6(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
nofusion_strongforhigher = ResNet_v7(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
strongwithnorm = ResNet_v8(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
strongforhigher_light = ResNet_v9(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
strongforhigher_jacobian = ResNet_v10(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
strongforhigher_strongwithtran = ResNet_v11(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
lessdiv_strongforhigher321 = ResNet_v12(x_train=x_train, y_train=y_train, x_val=x_test, y_val=y_test, load_weights=False)

# %%
fusion.train()

# %%
fusion._model.save_weights('models/resnet_32_fusion_diversity_avg_weight_final.h5')

# %%
nofusion.train()

# %%
nofusion._model.save_weights('models/resnet_32_nofusion_diversity_avg_weight_final.h5')

# %%
nofusion_nodiversity.train()

# %%
nofusion_nodiversity._model.save_weights('models/resnet_32_nofusion_nodiversity_avg_weight_final.h5')

# %%
fusion_nodiversity.train()

# %%
fusion_nodiversity._model.save_weights('models/resnet_32_fusion_nodiversity_avg_weight_final.h5')

# %%
strongforhigher.train()

# %%
strongforhigher._model.save_weights('models/resnet_32_fusion_diversity_strongforhigher_avg_weight_final.h5')

# %%
nofusion_strongforhigher.train()

# %%
nofusion_strongforhigher._model.save_weights('models/resnet_32_nofusion_diversity_strongforhigher_avg_weight_final.h5')

# %%
strongwithnorm.train()

# %%
strongwithnorm._model.save_weights('models/resnet_32_fusion_diversity_strongwithnorm_avg_weight_final.h5')

# %%
strongforhigher_light.train()

# %%
strongforhigher_light._model.save_weights('models/resnet_32_fusion_diversity_strongforhigher_light_avg_weight_final.h5')

# %%
strongforhigher_jacobian.train()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# ...

# %%
strongforhigher_jacobian._model.save_weights('models/resnet_32_fusion_diversity_strongforhigher_jacobian_avg_weight_final.h5')

# %%
strongforhigher_strongwithtran.train()

# %%
strongforhigher_strong.train()

# %%
less_div.train()

# %%
lessdiv_strongforhigher.train()

# %%
lessdiv_strongforhigher321.train()
